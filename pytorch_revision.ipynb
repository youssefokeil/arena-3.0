# %% [markdown]
# # Pytorch

# %% [markdown]
# revising some of pytorch's core functionalities.

# %%
import torch 
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
